# %% [markdown]
# # Hypothesis Testing - Cumulative Lab
#
# ## Introduction
#
# In this cumulative lab, you will use pandas to clean up a dataset and perform some EDA, then perform statistical tests and interpret their results in order to answer some business questions.
#
# ## Objectives
#
# You will be able to:
#
# * Practice using a data dictionary
# * Practice using pandas to prepare data for statistical analysis
# * Practice identifying an appropriate statistical test for a given question
# * Practice defining the null and alternative hypotheses
# * Practice executing statistical tests and interpreting their results

# %% [markdown]
# ## Your Task: Analyzing Health Trends
#
# ![tissues and tea mug](images/sick_day.jpg)
#
# Photo by <a href="https://unsplash.com/@kellysikkema?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Kelly Sikkema</a> on <a href="/?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Business Understanding
#
# Flatiron Health Insurance (FHI) is a growing private healthcare insurance provider founded on the premise that using data and analytics can improve the health insurance industry by providing better care and offerings to its patients. Every year, the Center for Disease Control (CDC) conducts surveys to understand the latest demographic, health, and fitness trends. You have been tasked with analyzing the recently published results of the 2017-2018 survey and providing your recommendations back to the Chief Analytics Officer and Chief Marketing Officer. You have been assigned the task of taking a first look at the data and beginning to answer several key questions:
#
# 1. How does health status, represented by average number of days with bad physical health in the past month (`PHYSHLTH`), differ by state?
# 2. Digging deeper into the data, what are some factors that impact health (demographics, behaviors, etc.)?
#
# ### Data Understanding
#
# To get you started, the IT department formatted the data set into a tab delimited text file for only NY, NJ, and CT (FHI’s primary markets) called `case_study.csv`.
#
# There is also a PDF data dictionary called `data_dictionary.pdf`, which explains the meanings of the features and codes contained in this dataset.
#
# Both files are located in the `data/` directory of this repository.
#
# Prior to each statistical test, you will need to perform some data preparation, which could include:
#
# * Filtering out rows with irrelevant values
# * Transforming data from codes into human-readable values
# * Binning data to transform it from numeric to categorical
# * Creating new columns based on queries of the values in other columns
#
# For steps 2-5, you will need to select and execute an appropriate statistical test. Recall these tests we have learned so far:
#
# 1. [Chi-squared test](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2_contingency.html): used for comparing a categorical feature against a categorical feature, to determine whether they are independent
# 2. [t-test](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html): used for comparing two categories of a numeric feature, to determine whether their means are the same across categories
# 3. [ANOVA](https://www.statsmodels.org/stable/generated/statsmodels.stats.anova.anova_lm.html#statsmodels.stats.anova.anova_lm): used for comparing more than two categories of a numeric feature, to determine whether their means are the same across categories

# %% [markdown]
# ### Requirements
#
# #### 1. Prepare `PHYSHLTH` Data for Analysis
#
# Using the data dictionary, ensure that you understand the meaning of the `PHYSHLTH` column. Then clean the data so that only valid records of `PHYSHLTH` remain.
#
# #### 2. Describe the Distribution of Health Status by State
#
# Does health status (`PHYSHLTH`) differ by state (`STATE_`)? If so, by how much, and is it statistically significant?
#
# #### 3. Describe the Relationship between Health Status and Home Ownership Status
#
# Does health status (`PHYSHLTH`) differ between home owners and renters (`RENTHOM1`)? If so, by how much, and is it statistically significant?
#
# #### 4. Describe the Relationship between Chronic Sickness and Nicotine Use
#
# Does chronic sickness (`PHYSHLTH >= 15`) differ based on nicotine use (various columns)? If so, by how much, and is it statistically significant?
#
# #### 5. Choose Your Own Question
#
# Thinking about the business case, what is another question that might be useful to answer? Perform all analysis steps to answer this question.

# %% [markdown]
# ## 1. Prepare `PHYSHLTH` Data for Analysis
#
# In the cells below, we include the relevant imports and load the data into a dataframe called `df`:

# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Run this cell without changes
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import math
import scipy.stats as stats
import seaborn as sns
import random
sns.set_style('whitegrid')
# %config InlineBackend.figure_format = 'retina'

# %%
# Run this cell without changes
df = pd.read_csv("data/case_study.csv", index_col=0, low_memory=False)
df
# Out:
#         _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938      9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939      9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940      9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941      9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942      9.0     5.0  7182017       7    18   2017    1200.0  2017000005
# ...        ...     ...      ...     ...   ...    ...       ...         ...
# 303774    36.0     5.0  5152017       5    15   2017    1200.0  2017012245
# 303775    36.0     6.0  6252017       6    25   2017    1200.0  2017012246
# 303776    36.0     7.0  7212017       7    21   2017    1200.0  2017012247
# 303777    36.0     7.0  7202017       7    20   2017    1200.0  2017012248
# 303778    36.0     7.0  7252017       7    25   2017    1200.0  2017012249
#
# ...

# %%
print(df.columns)
# Out:
# Index(['_STATE', 'FMONTH', 'IDATE', 'IMONTH', 'IDAY', 'IYEAR', 'DISPCODE',
#        'SEQNO', '_PSU', 'CTELENM1',
#        ...
#        '_PA300R2', '_PA30021', '_PASTRNG', '_PAREC1', '_PASTAE1', '_RFSEAT2',
#        '_RFSEAT3', '_FLSHOT6', '_PNEUMO2', '_AIDTST3'],
#       dtype='object', length=358)

# %% [markdown]
# Our main column of interest is called `PHYSHLTH`. We display summary statistics and plot a distribution below:

# %%
# Run this cell without changes
df['PHYSHLTH'].describe()
# Out:
# count    34545.000000
# mean        60.213403
# std         37.504566
# min          1.000000
# 25%         15.000000
# 50%         88.000000
# 75%         88.000000
# max         99.000000
# Name: PHYSHLTH, dtype: float64

# %%
# Run this cell without changes
fig, ax = plt.subplots()
ax.hist(df["PHYSHLTH"], bins="auto")
ax.set_xlabel("PHYSHLTH")
ax.set_ylabel("Count")
ax.set_title("Distribution of PHYSHLTH in Raw Data");

# %% [markdown]
# This feature is supposed to represent the number of days with bad physical health out of the past 30 days. Do you see anything wrong with what is displayed above? Explain.

# %%
# Replace None with appropriate text
"""
Out-of-Range Values:
The histogram shows values beyond the expected range of 0 to 30 days. Specifically, there are values around 70 to 100, which are not valid .
Missing Data
The histogram indicates missing counts for certain ranges (e.g., from about 30 days to 78 days). This could be due to missing data or incorrect data entries.There are some days with missing counts (from about 30 days to 78 days)
Data Encoding Issues:
The data might include special codes for missing values, such as 77 for "Don't know/Not sure," 88 for "Refused," and 99 for "Not asked or Missing." and should be  either converted to NaN or excluding them from the analysis.
"""
# Out:
# '\nOut-of-Range Values:\nThe histogram shows values beyond the expected range of 0 to 30 days. Specifically, there are values around 70 to 100, which are not valid .\nMissing Data\nThe histogram indicates missing counts for certain ranges (e.g., from about 30 days to 78 days). This could be due to missing data or incorrect data entries.There are some days with missing counts (from about 30 days to 78 days)\nData Encoding Issues:\nThe data might include special codes for missing values, such as 77 for "Don\'t know/Not sure," 88 for "Refused," and 99 for "Not asked or Missing." and should be  either converted to NaN or excluding them from the analysis.\n'

# %% [markdown]
# Look in the data dictionary, page 17, to understand what is happening with these values. Then edit the cell below so:
#
# * The records where the `PHYSHLTH` value label is `None` are converted to 0
# * The records where the `PHYSHLTH` value label is `Number of days` are kept as-is
# * All other records are dropped (i.e. records with `Don't know/Not sure`, `Refused`, and `Not asked or Missing` value labels for `PHYSHLTH` are dropped)

# %%
df.loc[df['PHYSHLTH'] == 88, 'PHYSHLTH'] = 0


df = df[~df['PHYSHLTH'].isin([77, 99, 'BLANK'])]


df['PHYSHLTH'] = pd.to_numeric(df['PHYSHLTH'])
# Out:
# C:\Users\FLEX 5\AppData\Local\Temp\ipykernel_26012\3672302581.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PHYSHLTH'] = pd.to_numeric(df['PHYSHLTH'])

# %%
# Your code here
# Replace None with 0
df['PHYSHLTH']
# Out:
# 49938     0.0
# 49939     0.0
# 49940     2.0
# 49941     0.0
# 49942     0.0
#          ...
# 303774    0.0
# 303775    0.0
# 303776    6.0
# 303777    0.0
# 303778    0.0
# Name: PHYSHLTH, Length: 33747, dtype: float64

# %% [markdown]
# Run the code below to ensure you have the correct, cleaned dataframe:

# %%
# Run this cell without changes

# We should have fewer rows, the same number of columns
assert df.shape == (33747, 358)

# The maximum value in this column should now be 30
assert df["PHYSHLTH"].max() == 30.0

# %% [markdown]
# Now we can look at the same descriptive information on our cleaned data:

# %%
# Run this cell without changes
df['PHYSHLTH'].describe()
# Out:
# count    33747.000000
# mean         4.085341
# std          8.513293
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max         30.000000
# Name: PHYSHLTH, dtype: float64

# %%
# Run this cell without changes
fig, ax = plt.subplots()
ax.hist(df["PHYSHLTH"])
ax.set_xlabel("PHYSHLTH")
ax.set_ylabel("Count")
ax.set_title("Distribution of PHYSHLTH in Cleaned Data");

# %% [markdown]
# That looks a lot more reasonable. Let's move on to the next step.

# %% [markdown]
# ## 2. Describe the Distribution of Health Status by State
#
# As mentioned previously, this dataset only includes data from three states.

# %%
# Run this cell without changes
df["_STATE"].value_counts()
# Out:
# _STATE
# 36.0    11876
# 34.0    11458
# 9.0     10413
# Name: count, dtype: int64

# %% [markdown]
# Look in the data dictionary, pages 2-3, to determine which states map onto which codes. Then replace the numbers with strings representing the state names.

# %%
# Your code here
df['_STATE'] = df['_STATE'].apply(lambda x: 'Connecticut' if x == 9 else ('New Jersey' if x == 34 else ('New York' if x == 36 else x)))
# Out:
# C:\Users\FLEX 5\AppData\Local\Temp\ipykernel_26012\2551399756.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['_STATE'] = df['_STATE'].apply(lambda x: 'Connecticut' if x == 9 else ('New Jersey' if x == 34 else ('New York' if x == 36 else x)))

# %% [markdown]
# Below, we check the values:

# %%
# Run this cell without changes

# Shape should be the same
assert df.shape == (33747, 358)

# Values in state column should be changed
assert sorted(list(df["_STATE"].value_counts().index)) == ['Connecticut', 'New Jersey', 'New York']

# %%
# Run this cell without changes

ny = df.loc[df["_STATE"] == "New York", "PHYSHLTH"]
nj = df.loc[df["_STATE"] == "New Jersey", "PHYSHLTH"]
ct = df.loc[df["_STATE"] == "Connecticut", "PHYSHLTH"]

fig, ax = plt.subplots(figsize=(15, 6))

ax.hist(
    x=[ny, nj, ct],
    label=["New York", "New Jersey", "Connecticut"],
    bins=range(32),
    align="left"
)

ax.set_xlabel("PHYSHLTH")
ax.set_ylabel("Count")
ax.set_title("Distribution of PHYSHLTH by State")

ax.legend(title="State");

# %% [markdown]
# Looking at the plot above, does the distribution seem to differ by state?
#
# (Just answer based on a visual inspection; we will do the statistical assessment next.)

# %%
# Replace None with appropriate text
"""
High Frequency at Zero for all 3 States indicating that many respondents reported 0 physically unhealthy days in the past 30 days.

The distributions for New York, New Jersey, and Connecticut are similar, with the highest counts at 0 and decreasing counts as the number of unhealthy days increases.
There are small peaks  values (e.g., 30), which might indicate a reporting pattern or specific health issues.

Comparing  Across States, the distributions for the three states do not appear to differ significantly. They all follow a similar pattern with a high frequency at 0 and a gradual decrease in counts as the number of unhealthy days increases.

Based on the visual inspection of the graph, the distribution of PHYSHLTH does not seem to differ significantly by state. All three states show a similar pattern with a high count of respondents reporting 0 physically unhealthy days and a gradual decrease in counts as the number of unhealthy days increases.
"""
# Out:
# '\nHigh Frequency at Zero for all 3 States indicating that many respondents reported 0 physically unhealthy days in the past 30 days.\n\nThe distributions for New York, New Jersey, and Connecticut are similar, with the highest counts at 0 and decreasing counts as the number of unhealthy days increases.\nThere are small peaks  values (e.g., 30), which might indicate a reporting pattern or specific health issues.\n\nComparing  Across States, the distributions for the three states do not appear to differ significantly. They all follow a similar pattern with a high frequency at 0 and a gradual decrease in counts as the number of unhealthy days increases.\n\nBased on the visual inspection of the graph, the distribution of PHYSHLTH does not seem to differ significantly by state. All three states show a similar pattern with a high count of respondents reporting 0 physically unhealthy days and a gradual decrease in counts as the number of unhealthy days increases.\n'

# %% [markdown]
# For the statistical test, we will be comparing the *means* of `PHYSHLTH` across states, as a representation of the overall distribution. In other words, when operationalizing the question **does `PHYSHLTH` differ by state?** we want to answer that in terms of the mean `PHYSHLTH`.
#
# Let's look at those means:

# %%
# Run this cell without changes
df.groupby("_STATE")["PHYSHLTH"].mean()
# Out:
# _STATE
# Connecticut    3.688562
# New Jersey     4.380957
# New York       4.148030
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# You likely noted that the overall distribution looked about the same, but these means are different. We have a range from Connecticut with about 3.7 days of bad health to New Jersey with about 4.4 days. But is that difference statistically significant?

# %% [markdown]
# Identify which of the statistical tests you have learned is the most appropriate for this question, and why. Make sure you mention what kinds of variables are being compared (numeric and categorical), and how many categories there are.

# %%
# Replace None with appropriate text
"""
To determine if these differences are statistically significant, we need to perform an appropriate statistical test. Given that we are comparing the means of a numeric variable (PHYSHLTH) across 3 categorical groups (states), the most appropriate test is the Analysis of Variance (ANOVA).

Numeric Variable: PHYSHLTH (number of physically unhealthy days)
Categorical Variable: _STATE (with three categories: New York, New Jersey, Connecticut)
Number of Categories: There are three categories (states).
"""
# Out:
# '\nTo determine if these differences are statistically significant, we need to perform an appropriate statistical test. Given that we are comparing the means of a numeric variable (PHYSHLTH) across 3 categorical groups (states), the most appropriate test is the Analysis of Variance (ANOVA).\n\nNumeric Variable: PHYSHLTH (number of physically unhealthy days)\nCategorical Variable: _STATE (with three categories: New York, New Jersey, Connecticut)\nNumber of Categories: There are three categories (states).\n'

# %% [markdown]
# Now, identify the null and alternative hypotheses:

# %%
# Replace None with appropriate text
"""
NULL HYPOTHESIS
All means of the 3 states  are equal

ALTERNATIVE HYPOTHESIS
At least one group mean is different.
"""
# Out:
# '\nNULL HYPOTHESIS\nAll means of the 3 states  are equal\n\nALTERNATIVE HYPOTHESIS\nAt least one group mean is different.\n'

# %% [markdown]
# In the cell below, we set up and execute the statistical test for you. If this doesn't match your previous answer about which test to perform, look at the solution branch to understand why this is the appropriate test.

# %%
# Run this cell without changes
import statsmodels.api as sm
from statsmodels.formula.api import ols

formula = 'PHYSHLTH ~ C(_STATE)'
lm = ols(formula, df).fit()
sm.stats.anova_lm(lm)
# Out:
#                 df        sum_sq      mean_sq          F        PR(>F)
# C(_STATE)      2.0  2.687322e+03  1343.660882  18.558645  8.800607e-09
# Residual   33744.0  2.443093e+06    72.400809        NaN           NaN

# %% [markdown]
# Interpret the results of this statistical test below. What is the calculated p-value? Were we able to reject the null hypothesis at an alpha of 0.05? What does this say about how `PHYSHLTH` varies by state? What recommendations would you make to the business?

# %%
# Replace None with appropriate text
"""
The p-value is, which is a very small value against the alpha 0.05(significance level) thus we reject the null hypothesis

The ANOVA test indicates that there are statistically significant differences in the mean number of physically unhealthy days (PHYSHLTH) among the three states (New York, New Jersey, and Connecticut). This means that the observed differences in the means (Connecticut: 3.7 days, New Jersey: 4.4 days, New York: 4.1 days) are not due to random chance.
I recommend the following
Conduct post-hoc tests (e.g., Tukey's HSD) to determine which specific pairs of states have significant differences in their means.
Investigate potential factors contributing to the differences in physically unhealthy days among the states, such as healthcare access, socioeconomic status, and lifestyle factors.
Health insurance premium payments should be revised or priced according  to state as loaction risk plays a big factor when underwriting the premium state like new jersey will have more health claims compared to connecticut and thus resients in newjersey should pay higher premiums compared to others"""
# Out:
# "\nThe p-value is, which is a very small value against the alpha 0.05(significance level) thus we reject the null hypothesis\n\nThe ANOVA test indicates that there are statistically significant differences in the mean number of physically unhealthy days (PHYSHLTH) among the three states (New York, New Jersey, and Connecticut). This means that the observed differences in the means (Connecticut: 3.7 days, New Jersey: 4.4 days, New York: 4.1 days) are not due to random chance.\nI recommend the following\nConduct post-hoc tests (e.g., Tukey's HSD) to determine which specific pairs of states have significant differences in their means.\nInvestigate potential factors contributing to the differences in physically unhealthy days among the states, such as healthcare access, socioeconomic status, and lifestyle factors.\nHealth insurance premium payments should be revised or priced according  to state as loaction risk plays a big factor when underwriting the premium state like new jersey will h
# ...

# %% [markdown]
# With that section wrapped up, let's move on to the next step.

# %% [markdown]
# ## 3. Describe the Relationship between Health Status and Home Ownership Status
#
# This time, we want to categorize respondents by demographic information: specifically, we'll look at whether or not they own their home.
#
# Once again, this will require some data preparation. The variable of interest is contained in the `RENTHOM1` column. Currently the values look like this:

# %%
# Run this cell without changes
df["RENTHOM1"].value_counts()
# Out:
# RENTHOM1
# 1.0    21690
# 2.0    10244
# 3.0     1526
# 9.0      194
# 7.0       93
# Name: count, dtype: int64

# %% [markdown]
# In the cell below, modify `df` so that we have dropped all records where the `RENTHOM1` value label is neither `Own` nor `Rent`, and we have replaced the numeric codes with `Own` and `Rent` respectively. You can find more information about codes on page 33 of the data dictionary.

# %%
# Your code here
df = df[df['RENTHOM1'].isin([1.0, 2.0])]

# Replace numeric codes with labels
df['RENTHOM1'] = df['RENTHOM1'].replace({1.0: 'Own', 2.0: 'Rent'})
# Out:
# C:\Users\FLEX 5\AppData\Local\Temp\ipykernel_26012\2005606567.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RENTHOM1'] = df['RENTHOM1'].replace({1.0: 'Own', 2.0: 'Rent'})

# %%
# Run this cell without changes
df["RENTHOM1"].value_counts()
# Out:
# RENTHOM1
# Own     21690
# Rent    10244
# Name: count, dtype: int64

# %% [markdown]
# Below, we check that this was done correctly:

# %%
# Run this cell without changes

# Number of rows should be smaller again
assert df.shape == (31934, 358)

# Only two values should be present in this column
assert sorted(list(df["RENTHOM1"].value_counts().index)) == ['Own', 'Rent']

# %% [markdown]
# Now, similar to the previous step, create a plot that shows the distribution of `PHYSHLTH` for those who own vs. rent their homes, including appropriate axis labels and legend. Because there is more of an imbalance of categories this time (more than twice as many owners as renters, compared to nearly-even numbers from New York, New Jersey, and Connecticut), make sure you add the argument `density=True`, so that the y-axis shows the density (proportion) rather than the count.

# %%
# Your code here
owned= df.loc[df["RENTHOM1"] == "Own", "PHYSHLTH"]
rented = df.loc[df["RENTHOM1"] == "Rent", "PHYSHLTH"]


fig, ax = plt.subplots(figsize=(15, 6))

ax.hist(
    x=[owned,rented],
    density = True,
    label=['Owned','Rented'],
    bins=range(32),
    align="left"
)

ax.set_xlabel("Number of Days Physical Health Not Good")
ax.set_ylabel("Density")
ax.set_title("Distribution of Physical Health (PHYSHLTH) for Home Owners vs. Renters")

ax.legend(title="Home Ownership");

# %% [markdown]
# Then run this code to find the averages:

# %%
# Run this cell without changes
df.groupby("RENTHOM1")["PHYSHLTH"].mean()
# Out:
# RENTHOM1
# Own     3.531213
# Rent    5.197970
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# Now, interpret the plot and averages. Does it seem like there a difference in the number of unhealthy days between those who rent their homes and those who own their homes? How does this compare to the distributions by state?

# %%
# Replace None with appropriate text
"""

Both owners and renters have a high proportion of respondents reporting zero unhealthy days.
The proportion is slightly higher for owners compared to renters.

The distribution for renters shows a slightly higher density for non-zero unhealthy days compared to owners.
Renters have a more spread-out distribution with noticeable densities at various points, including the higher end (30 days).

The distribution by state did not show significant differences, suggesting that the state itself might not be a major factor in the number of unhealthy days.
Visual analysis shows T a noticeable difference in the number of unhealthy days between those who rent and those who own their homes. Renters report more unhealthy days on average compared to owners. This difference is more pronounced than any variations observed by state, highlighting the potential influence of home ownership status on physical health.
"""
# Out:
# '\n\nBoth owners and renters have a high proportion of respondents reporting zero unhealthy days.\nThe proportion is slightly higher for owners compared to renters.\n\nThe distribution for renters shows a slightly higher density for non-zero unhealthy days compared to owners.\nRenters have a more spread-out distribution with noticeable densities at various points, including the higher end (30 days).\n\nThe distribution by state did not show significant differences, suggesting that the state itself might not be a major factor in the number of unhealthy days.\nVisual analysis shows T a noticeable difference in the number of unhealthy days between those who rent and those who own their homes. Renters report more unhealthy days on average compared to owners. This difference is more pronounced than any variations observed by state, highlighting the potential influence of home ownership status on physical health.\n'

# %% [markdown]
# Now, choose and execute an appropriate statistical test. Make sure you describe why you chose the test, the null and alternative hypotheses, and what the result of the test means.

# %%
# Your code here (create additional cells as needed)
"""
Null Hypothesis 
There is no difference in the mean of unhealthy days (PHYSHLTH) between individuals who own their homes and those who rent their homes.
Alternative Hypothesis
There is a difference in the mean of unhealthy days (PHYSHLTH) between individuals who own their homes and those who rent their homes.
"""
# Out:
# '\nNull Hypothesis \nThere is no difference in the mean of unhealthy days (PHYSHLTH) between individuals who own their homes and those who rent their homes.\nAlternative Hypothesis\nThere is a difference in the mean of unhealthy days (PHYSHLTH) between individuals who own their homes and those who rent their homes.\n'

# %%
""""
test to be used is the  independent samples t-test chosen significance level(alpha) 0.05

Reason
two independent variables(homeowners and Renters)to determine if there is a statistically significant difference between them.
"""
# Out:
# '"\ntest to be used is the  independent samples t-test chosen significance level(alpha) 0.05\n\nReason\ntwo independent variables(homeowners and Renters)to determine if there is a statistically significant difference between them.\n'

# %%
t_stat, p_value = stats.ttest_ind(owned, rented, equal_var=False)
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")
# Out:
# T-statistic: -15.480104856835828
# P-value: 1.0789298641635188e-53

# %%
"""
p- value is significantly less  than  0.05,thus I   conclude that there is a significant difference and thus reject the null hypothesis There is difference in the mean of unhealthy days (PHYSHLTH) between individuals who own their homes and those who rent their homes.
"""
# Out:
# '\np- value is significantly less  than  0.05,thus I   conclude that there is a significant difference and thus reject the null hypothesis There is difference in the mean of unhealthy days (PHYSHLTH) between individuals who own their homes and those who rent their homes.\n'

# %% [markdown]
# ## 4. Describe the Relationship between Chronic Sickness and Nicotine Use
#
# Once again, this will require some preparation before we can run the statistical test. Create a new column `NICOTINE_USE` with 1 representing someone who uses or has used nicotine in some form, and 0 representing someone who hasn't.
#
# We define nicotine use as:
#
# * Answered `Yes` to the `SMOKE100` question (*Have you smoked at least 100 cigarettes in your entire life?*, page 43), OR
# * Answered `Every day` or `Some days` to the `USENOW3` question (*Do you currently use chewing tobacco, snuff, or snus every day, some days, or not at all?*, page 46), OR
# * Answered `Yes` to the `ECIGARET` question (*Have you ever used an e-cigarette or other electronic vaping product, even just one time, in your entire life?*, page 46)
#
# If a record matches one or more of the above criteria, `NICOTINE_USE` should be 1. Otherwise, `NICOTINE_USE` should be 0. Go ahead and keep all of the "Don't know" or "Refused" answers as 0.

# %%
# Your code here
condition_smoke100 = df['SMOKE100'] == 1
condition_usenow3 = df['USENOW3'].isin([1, 2])
condition_ecigaret = df['ECIGARET'] == 1
df['NICOTINE_USE'] = (condition_smoke100 | condition_usenow3 | condition_ecigaret).astype(int)


# Look at the distribution of values
df["NICOTINE_USE"].value_counts(normalize=True)
# Out:
# C:\Users\FLEX 5\AppData\Local\Temp\ipykernel_26012\2871560894.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NICOTINE_USE'] = (condition_smoke100 | condition_usenow3 | condition_ecigaret).astype(int)
# NICOTINE_USE
# 0    0.563036
# 1    0.436964
# Name: proportion, dtype: float64

# %% [markdown]
# This time, let's treat health status as a categorical variable. We'll say that a "chronically sick" person is a person who reports that their physical health was not good for 15 or more out of the past 30 days. (This is a simplification but it will work for this analysis.)
#
# In the cell below, create a new column of `df` called `CHRONIC`, which is 0 for records where `PHYSHLTH` is less than 15, and 1 for records where `PHYSHLTH` is 15 or more.

# %%
# Your code here
very_sick = df['PHYSHLTH']>= 15
slightly_sick = df['PHYSHLTH']< 15
df['CHRONIC'] = (very_sick).astype(int)

# View the distribution of the newly-created column
df["CHRONIC"].value_counts()
# Out:
# C:\Users\FLEX 5\AppData\Local\Temp\ipykernel_26012\1185433810.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CHRONIC'] = (very_sick).astype(int)
# CHRONIC
# 0    28246
# 1     3688
# Name: count, dtype: int64

# %% [markdown]
# Now we can view the crosstabs for these two categorical variables, as well as display their distributions:

# %%
# Run this cell without changes
contingency_table = pd.crosstab(index=df["CHRONIC"], columns=df["NICOTINE_USE"])
contingency_table
# Out:
# NICOTINE_USE      0      1
# CHRONIC
# 0             16332  11914
# 1              1648   2040

# %%
# Run this cell without changes

no_nicotine_use = df.loc[df["NICOTINE_USE"] == 0, "CHRONIC"]
nicotine_use = df.loc[df["NICOTINE_USE"] == 1, "CHRONIC"]

fig, ax = plt.subplots()

ax.hist(
    x=[no_nicotine_use, nicotine_use],
    label=["No Nicotine Use", "Nicotine Use"],
    bins=[0,1,2],
    align="left"
)

ax.set_ylabel("Count")
ax.set_xticks([0,1])
ax.set_xticklabels(["Not Chronically Sick", "Chronically Sick"])
ax.set_title("Distribution of Chronic Sickness by Nicotine Use")

ax.legend();

# %% [markdown]
# Once again, it appears that there is a difference in health outcomes between these categories. In the cell below, select an appropriate statistical test, describe the null and alternative hypotheses, execute the test, and interpret the result.

# %%
# Your code here (create additional cells as needed)
"""
NULL Hypothesis
There is no difference in the proportion of chronic sickness between individuals who use nicotine and those who do not.
ALTERNATIVE Hypothesis
There is a difference in the proportion of chronic sickness between individuals who use nicotine and those who do not.
Test to be Used 
we are comparing proportions between two independent groups (nicotine users and non-users), I choose the Chi-Square Test for Independence.
Significance level 0.05

# %%
from scipy.stats import chi2_contingency
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-Square Statistic: 228.22648537455362
# P-value: 1.4525226945056695e-51

# %%
"""
the p-value is significantly less  than the significance level, thus i  reject the null hypothesis.
I  have significant evidence to conclude that there is a significant association between between nicotine use and chronic sickness
"""

# %% [markdown]
# ## 5. Choose Your Own Question
#
# Now that you have investigated physical health and chronic sickness and their relationships with state, home ownership, and nicotine use, you will conduct a similar investigation with variables of your choosing.
#
# Select an independent variable based on looking at the information in the data dictionary, and perform any additional transformations needed to use it in an analysis. Then set up, execute, and interpret a statistical test that addresses the relationship between that independent variable and `PHYSHLTH`.
#
# (There is no solution branch for this question, and feel free to move on if you have already spent more than 1.5 hours on this lab.)

# %%
# Your code here (create additional cells as needed)

# %% [markdown]
# ## Conclusion
#
# Congratulations, another cumulative lab down! In this lab you practiced reading a data dictionary, performing various data transformations with pandas, and executing statistical tests to address business questions.
